# %% [markdown]
# # Cap Stone Python

# %% [markdown]
# #### Importing the data frame a Stress

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # standard
import csv
import seaborn as sns
from  itertools import groupby
from decimal import Decimal

mcu = pd.read_csv("mcu dataset.csv")
mcu
# Out:
#                                     Name    US release Date  \
# 0                               Iron Man        May 2, 2008
# 1                    The incredible Hulk      June 13, 2008
# 2                             Iron Man 2        May 7, 2010
# 3                                   Thor        May 6, 2011
# 4     Captain America: The first Avenger      July 22, 2011
# 5                  Marvel's the Avengers        May 4, 2012
# 6                             Iron Man 3        May 3, 2013
# 7                   Thor: The dark world   November 8, 2013
# 8   Captain America : The Winter Soldier      April 4, 2014
# 9                Guardians Of the Galaxy     August 1, 2014
# 10              Avengers : Age of ultron        May 1, 2015
# 11                               Ant-Man      July 17, 2015
# 12            Captain America: Civil War        May 6, 2016
# 13                       Doctor Strange    November 4, 2016
# 14        Guardians of the Galaxy Vol. 2        May 5, 2017
# 15                 Spider-Man:Homecoming       July 7, 2017
# 16                         Thor:Ragnarok   November 3, 2017
# 17                         Black Panther  February 16, 2018
# 18                Avengers: Infinity War     April 27, 2018
# 19                  Ant-Man and the Wasp       July 6, 2018
# 20                        Captain-Marvel      March 8, 2019
# 21                      Avengers:Endgame     April 26, 2019
# 22              Spider-Man:Far From Home       July 2, 2019
#
#                      Director                                 Producer  \
# 0                 Jon Favreau                 Avi Arad and Kevin Feige
# 1             Louis Leterrier  Avi Arad ,Gale Ann Hurd and Kevin Feige
# 2                 Jon Favreau                              Kevin Feige
# 3             Kenneth Branagh                              Kevin Feige
# 4                Joe Jhonston                              Kevin Feige
# 5                 Joss Whedon                              Kevin Feige
# 6                 Shane Black                              Kevin Feige
# 7                 Alan Taylor                              Kevin Feige
# 8       Anthony and Joe Russo                              Kevin Feige
# 9                  James Gunn                              Kevin Feige
# 10                Joss Whedon                              Kevin Feige
# 11                Peyton Reed                              Kevin Feige
# 12      Anthony and Joe Russo                              Kevin Feige
# 13           Scott Derrickson                              Kevin Feige
# 14                 James Gunn                              Kevin Feige
# 15                  Jon Watts               Kevin Feige and Amy Pascal
# 16              Taika Waititi                              Kevin Feige
# 17               Ryan Coogler                              Kevin Feige
# 18      Anthony and Joe Russo                              Kevin Feige
# 19                Peyton Reed        Kevin Feige and Stephen Broussard
# 20  Anna Boden and Ryan Fleck                              Kevin Feige
# 21      Anthony and Joe Russo                              Kevin Feige
# 22                  Jon Watts               Kevin Feige and Amy Pascal
#
#     Duration                        Genre  IMDB rating  metascore  \
# 0    2h 6min   Action , Adventure, Sci-Fi          7.9         79
# 1   1h 52min   Action , Adventure, Sci-Fi          6.6         61
# 2    2h 4min   Action , Adventure, Sci-Fi          7.0         57
# 3   1h 55min  Action , Adventure, Fantasy          7.0         57
# 4    2h 4min   Action , Adventure, Sci-Fi          6.9         66
# 5   2h 23min   Action , Adventure, Sci-Fi          8.0         69
# 6   2h 10min   Action , Adventure, Sci-Fi          7.1         62
# 7   1h 52min  Action , Adventure, Fantasy          6.8         54
# 8   2h 16min   Action , Adventure, Sci-Fi          7.7         70
# 9    2h 1min   Action, Adventure , Comedy          8.0         76
# 10  2h 21min   Action , Adventure, Sci-Fi          7.3         66
# 11  1h 57min   Action, Adventure , Comedy          7.3         64
# 12  2h 27min   Action , Adventure, Sci-Fi          7.8         75
# 13  1h 55min  Action , Adventure, Fantasy          7.5         72
# 14  2h 16min   Action, Adventure , Comedy          7.6         67
# 15  2h 13min   Action , Adventure, Sci-Fi          7.4         73
# 16  2h 10min   Action, Adventure , Comedy          7.9         74
# 17  2h 14min   Action , Adventure, Sci-Fi          7.3         88
# 18  2h 29min   Action , Adventure, Sci-Fi          8.4         68
# 19  1h 58min   Action, Adventure , Comedy          7.0         70
# 20   2h 3min   Action , Adventure, Sci-Fi          6.8         64
# 21   3h 1min   Action , Adventure , Drama          8.4         78
# 22   2h 9min   Action , Adventure, Sci-Fi          7.5         69
#
#                                                  Cast        Budget  \
# 0   Robert Downey Jr. , Gweneth Paltrow , Terrence...  $140,000,000
# 1                Edward Norton , Liv Tyler , Tim Roth  $150,000,000
# 2   Robert Downey Jr. , Gweneth Paltrow , Mickey R...  $200,000,000
# 3   Chris Hemsworth , Anthony Hopkins , Natalie Po...  $150,000,000
# 4     Chris Evans ,  Hugo Weaving , Samuel L. Jackson  $140,000,000
# 5   Robert Downey Jr. , Chris Evans , Scarlett Joh...  $220,000,000
# 6    Robert Downey Jr. , Gweneth Paltrow , Guy Pearce  $200,000,000
# 7   Chris Hemsworth ,  Natalie Portman , Tom Hiddl...  $170,000,000
# 8   Chris Evans , Scarlett Johansson , Samuel L. J...  $170,000,000
# 9            Chris Patt , Vin Diesel , Bradely Cooper  $170,000,000
# 10  Robert Downey Jr. , Chris Evans , Chris Hemswo...  $250,000,000
# 11          Paul Rudd , Michael Douglas , Corey Stall  $130,000,000
# 12  Robert Downey Jr. , Chris Evans , Scarlett Joh...  $250,000,000
# 13  Benedict Cumberbatch , Chiswetel Ejiofor , Rac...  $165,000,000
# 14  Chris Patt ,  Zoe Saldana , Dave Bautista , Vi...  $200,000,000
# 15   Tom Holland , Michael Keaton , Robert Downey Jr.  $175,000,000
# 16  Chris Hemsworth ,  Cate Blanchett , Tom Hiddle...  $180,000,000
# 17  Chadwick Boseman , Michael B. Jordan , Lupita ...  $200,000,000
# 18  Robert Downey Jr. , Chris Evans , Chris Hemswo...  $300,000,000
# 19        Paul Rudd , Evangeline Lilly , Micheal Pena  $130,000,000
# 20   Brie Larson , Samuel L. Jackson , Ben Mendelsohn  $160,000,000
# 21  Robert Downey Jr. , Chris Evans , Chris Hemswo...  $356,000,000
# 22  Tom Holland , Samuel L. Jackson , Jake Gyllenhaal  $160,000,000
#
#    Domestic Gross     Total Gross Opening Gross  Oscar Nomination  Oscar won  \
# 0    $318,604,126    $585,366,247   $98,618,668                 2          0
# 1    $134,806,913    $264,770,996   $55,414,050                 0          0
# 2    $312,433,331    $623,933,331  $128,122,480                 1          0
# 3    $181,030,624    $449,326,618   $65,723,338                 0          0
# 4    $176,654,505    $370,569,774   $65,058,524                 0          0
# 5    $623,357,910  $1,518,812,988  $207,438,708                 1          0
# 6    $408,992,272  $1,214,811,252  $174,144,585                 1          0
# 7    $206,362,140    $644,783,140   $85,737,841                 0          0
# 8    $259,746,958    $714,421,503   $95,023,721                 1          0
# 9    $333,714,112    $772,776,600   $94,320,883                 2          0
# 10   $459,005,868  $1,402,805,868  $191,271,109                 0          0
# 11   $180,202,163    $519,311,965   $57,225,526                 0          0
# 12   $408,084,349  $1,153,296,293  $179,139,142                 0          0
# 13   $232,641,920    $677,718,395   $85,058,311                 1          0
# 14   $389,813,101    $863,756,051  $146,510,104                 1          0
# 15   $334,201,140    $880,166,924  $117,027,503                 0          0
# 16    $315,058,28    $853,977,126  $122,744,989                 0          0
# 17    $700,059,56  $1,346,913,161  $202,003,951                 7          3
# 18   $678,815,482  $2,048,359,754  $257,698,183                 1          0
# 19   $216,648,740    $622,674,139   $75,812,205                 0          0
# 20   $426,829,839  $1,128,274,794  $153,433,423                 0          0
# 21   $858,373,000  $2,797,501,328  $357,115,007                 1          0
# 22   $390,532,085  $1,131,927,996   $92,579,212                 0          0
#
#     Phase
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# 5       1
# 6       2
# 7       2
# 8       2
# 9       2
# 10      2
# 11      2
# 12      3
# 13      3
# 14      3
# 15      3
# 16      3
# 17      3
# 18      3
# 19      3
# 20      3
# 21      3
# 22      3

# %% [raw]
# List of directors Jon Favreau, Louis Leterrier, Kenneth Branagh, Joe Jhonston, Joss Whedon Shane Black, Alan Taylor, Anthony and Joe Russo James Gunn, Peyton Reed, Scott Derrickson, Jon Watts, Ryan Coogler, Anna Boden and Ryan Fleck

# %% [markdown]
# Hypthosesis Questions:
# Hypothesis:Robert Downy Jr. has the highest average gross profit of gross - budget?
# True
# Hypothesis:Captain america has the lowest average metascore of the actors?  check
# flase, Nately Portlan has it
# Hypothesis:What movie has the highest total profit gross - budget?
# endgame
# Hypothesis:What movie has the best meta score to budget-ratio?, check
# Iron man
# Hypothesis:What cast member is the least number of movies pointless
# many only have 1
# Hypothesis:What movie made the most money after its release total gross - opening, check
# endgame
# Hypothesis: What director has the highest average metascore: check
# IMDB.rating James Gunn, metacore of Ryan Coogler
# Hypothesis: What actor has the highest average meta score/IMDB.rating? check
# Chadwick Boseman, Tom Holland
#
# Hypothesis: Robert Downey Jr. Hast the most number of movies.check
#
# Hyptothesis: What cast member has the highest average metascore.cheeck
# Chadwick Boseman
# Hyptothesis: What cast member has the highest average IMDBD rating check
# Josh Brolin
# Hypothesis: What is the average meta score for all the movies: check
# The meta score avereage rating is  68.65217391304348
#
# The average IMDB Rating has an average score of 7.4434782608695675 check
#
# Hypothesis: What cast member is in the most movies. check
# Rober Downey Jr.
# Hypothesis: For each cast member what is the total number of the total gross check
# Robert Downey J.

# %%
#Making a budget in column
#replace the dollars signs with null with intergers
mcu['Budgetint'] = mcu['Budget'].str.replace('$', '')
#replace the , with null
mcu['Budgetint'] = mcu['Budgetint'].str.replace(',', '')
#Making a new column budget int to do math
mcu['Budgetint'] = mcu['Budgetint'].astype(np.int64)

#Making a totalgross in column
#replace the dollars signs with null with intergers
mcu['Total Gross Int'] = mcu['Total Gross'].str.replace('$', '')
#replace the , with null
mcu['Total Gross Int'] = mcu['Total Gross Int'].str.replace(',', '')
#Making a new column budget int to do math
mcu['Total Gross Int'] = mcu['Total Gross Int'].astype(np.int64)

#Making a new column of total profit
mcu['Total Profit'] = mcu['Total Gross Int']-mcu['Budgetint']

#Finding the ID and the Max of the movies
print(mcu.loc[mcu['Total Profit'].idxmax(),"Name"],max(mcu["Total Profit"]))
# Out:
# C:\Users\ryan\AppData\Local\Temp\ipykernel_9976\557510539.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   mcu['Budgetint'] = mcu['Budget'].str.replace('$', '')
# C:\Users\ryan\AppData\Local\Temp\ipykernel_9976\557510539.py:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   mcu['Total Gross Int'] = mcu['Total Gross'].str.replace('$', '')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 21
#      18 mcu['Total Profit'] = mcu['Total Gross Int']-mcu['Budgetint']
#      20 #Finding the ID and the Max of the movies
# ---> 21 print(mcu.loc[mcu['Total Profit'].idxmax(),"Name"],max(mcu["Total Profit"]))
#
# TypeError: 'numpy.float64' object is not callable

# %% [markdown]
# Find which movie has the best review to budget ratio?

# %%
#Making a budget in column
#replace the dollars signs with null with intergers
mcu['Budgetint'] = mcu['Budget'].str.replace('$', '')
#replace the , with null
mcu['Budgetint'] = mcu['Budgetint'].str.replace(',', '')
#Making a new column budget int to do math
mcu['Budgetint'] = mcu['Budgetint'].astype(np.int64)

#Review to budget ratio
mcu["Review to Budget"] = mcu["metascore"]/(mcu["Budgetint"])

#Finding the ID and the Max of the movie with the highest score and the lowest budget
print(mcu.loc[mcu['Review to Budget'].idxmax(),"Name"],max(mcu["Review to Budget"]))
# Out:
# C:\Users\ryan\AppData\Local\Temp\ipykernel_9976\3232171956.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   mcu['Budgetint'] = mcu['Budget'].str.replace('$', '')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 13
#      10 mcu["Review to Budget"] = mcu["metascore"]/(mcu["Budgetint"])
#      12 #Finding the ID and the Max of the movie with the highest score and the lowest budget
# ---> 13 print(mcu.loc[mcu['Review to Budget'].idxmax(),"Name"],max(mcu["Review to Budget"]))
#
# TypeError: 'numpy.float64' object is not callable

# %% [markdown]
# Hypothesis captain america has the lowest metascore? The anser is false by counter example of edward nortron

# %%
captain_america = mcu[mcu["Cast"].str.contains("Chris Evans")]
print(captain_america["metascore"].mean())
spiderman = mcu[mcu["Cast"].str.contains("Tom Holland")]
print(spiderman["metascore"].mean())
hulk = mcu[mcu["Cast"].str.contains("Edward Norton")]
print(hulk["metascore"].mean())
# Out:
# 70.28571428571429
# 71.0
# 61.0

# %% [markdown]
# what director has the highest average meta score.

# %%
Directors = ['Jon Favreau', 'Louis Leterrier', 'Kenneth Branagh', 'Joe Jhonston', 'Joss Whedon', 'Shane Black', 
             'Alan Taylor', 'Anthony and Joe Russo','James Gunn' ,'Peyton Reed', 'Scott Derrickson', 'Jon Watts', 
             'Ryan Coogler', 'Anna Boden and Ryan Fleck']
Director_list = []
for Director in Directors:
    director_metascore = mcu[mcu["Director"].str.contains(Director)]
    print(Director,"Has the average metascore:" ,director_metascore["metascore"].mean(), "has the count of movies" ,director_metascore["metascore"].count())
# Out:
# Jon Favreau Has the average metascore: 68.0 has the count of movies 2
# Louis Leterrier Has the average metascore: 61.0 has the count of movies 1
# Kenneth Branagh Has the average metascore: 57.0 has the count of movies 1
# Joe Jhonston Has the average metascore: 66.0 has the count of movies 1
# Joss Whedon Has the average metascore: 67.5 has the count of movies 2
# Shane Black Has the average metascore: 62.0 has the count of movies 1
# Alan Taylor Has the average metascore: 54.0 has the count of movies 1
# Anthony and Joe Russo Has the average metascore: 72.75 has the count of movies 4
# James Gunn Has the average metascore: 71.5 has the count of movies 2
# Peyton Reed Has the average metascore: 67.0 has the count of movies 2
# Scott Derrickson Has the average metascore: 72.0 has the count of movies 1
# Jon Watts Has the average metascore: 71.0 has the count of movies 2
# Ryan Coogler Has the average metascore: 88.0 has the count of movies 1
# Anna Boden and Ryan Fleck Has the average metascore: 64.0 has the count of movies 1

# %% [markdown]
# Ryan Coogler has the highest average meta score of all the directors, Alan Taylor has the worst score average metascore
# Anthony and Joe Russo have the highest number of movies

# %%
mcu
# Out:
#                                     Name    US release Date  \
# 0                               Iron Man        May 2, 2008
# 1                    The incredible Hulk      June 13, 2008
# 2                             Iron Man 2        May 7, 2010
# 3                                   Thor        May 6, 2011
# 4     Captain America: The first Avenger      July 22, 2011
# 5                  Marvel's the Avengers        May 4, 2012
# 6                             Iron Man 3        May 3, 2013
# 7                   Thor: The dark world   November 8, 2013
# 8   Captain America : The Winter Soldier      April 4, 2014
# 9                Guardians Of the Galaxy     August 1, 2014
# 10              Avengers : Age of ultron        May 1, 2015
# 11                               Ant-Man      July 17, 2015
# 12            Captain America: Civil War        May 6, 2016
# 13                       Doctor Strange    November 4, 2016
# 14        Guardians of the Galaxy Vol. 2        May 5, 2017
# 15                 Spider-Man:Homecoming       July 7, 2017
# 16                         Thor:Ragnarok   November 3, 2017
# 17                         Black Panther  February 16, 2018
# 18                Avengers: Infinity War     April 27, 2018
# 19                  Ant-Man and the Wasp       July 6, 2018
# 20                        Captain-Marvel      March 8, 2019
# 21                      Avengers:Endgame     April 26, 2019
# 22              Spider-Man:Far From Home       July 2, 2019
#
#                      Director                                 Producer  \
# 0                 Jon Favreau                 Avi Arad and Kevin Feige
# 1             Louis Leterrier  Avi Arad ,Gale Ann Hurd and Kevin Feige
# 2                 Jon Favreau                              Kevin Feige
# 3             Kenneth Branagh                              Kevin Feige
# 4                Joe Jhonston                              Kevin Feige
# 5                 Joss Whedon                              Kevin Feige
# 6                 Shane Black                              Kevin Feige
# 7                 Alan Taylor                              Kevin Feige
# 8       Anthony and Joe Russo                              Kevin Feige
# 9                  James Gunn                              Kevin Feige
# 10                Joss Whedon                              Kevin Feige
# 11                Peyton Reed                              Kevin Feige
# 12      Anthony and Joe Russo                              Kevin Feige
# 13           Scott Derrickson                              Kevin Feige
# 14                 James Gunn                              Kevin Feige
# 15                  Jon Watts               Kevin Feige and Amy Pascal
# 16              Taika Waititi                              Kevin Feige
# 17               Ryan Coogler                              Kevin Feige
# 18      Anthony and Joe Russo                              Kevin Feige
# 19                Peyton Reed        Kevin Feige and Stephen Broussard
# 20  Anna Boden and Ryan Fleck                              Kevin Feige
# 21      Anthony and Joe Russo                              Kevin Feige
# 22                  Jon Watts               Kevin Feige and Amy Pascal
#
#     Duration                        Genre  IMDB rating  metascore  \
# 0    2h 6min   Action , Adventure, Sci-Fi          7.9         79
# 1   1h 52min   Action , Adventure, Sci-Fi          6.6         61
# 2    2h 4min   Action , Adventure, Sci-Fi          7.0         57
# 3   1h 55min  Action , Adventure, Fantasy          7.0         57
# 4    2h 4min   Action , Adventure, Sci-Fi          6.9         66
# 5   2h 23min   Action , Adventure, Sci-Fi          8.0         69
# 6   2h 10min   Action , Adventure, Sci-Fi          7.1         62
# 7   1h 52min  Action , Adventure, Fantasy          6.8         54
# 8   2h 16min   Action , Adventure, Sci-Fi          7.7         70
# 9    2h 1min   Action, Adventure , Comedy          8.0         76
# 10  2h 21min   Action , Adventure, Sci-Fi          7.3         66
# 11  1h 57min   Action, Adventure , Comedy          7.3         64
# 12  2h 27min   Action , Adventure, Sci-Fi          7.8         75
# 13  1h 55min  Action , Adventure, Fantasy          7.5         72
# 14  2h 16min   Action, Adventure , Comedy          7.6         67
# 15  2h 13min   Action , Adventure, Sci-Fi          7.4         73
# 16  2h 10min   Action, Adventure , Comedy          7.9         74
# 17  2h 14min   Action , Adventure, Sci-Fi          7.3         88
# 18  2h 29min   Action , Adventure, Sci-Fi          8.4         68
# 19  1h 58min   Action, Adventure , Comedy          7.0         70
# 20   2h 3min   Action , Adventure, Sci-Fi          6.8         64
# 21   3h 1min   Action , Adventure , Drama          8.4         78
# 22   2h 9min   Action , Adventure, Sci-Fi          7.5         69
#
#                                                  Cast        Budget  \
# 0   Robert Downey Jr. , Gweneth Paltrow , Terrence...  $140,000,000
# 1                Edward Norton , Liv Tyler , Tim Roth  $150,000,000
# 2   Robert Downey Jr. , Gweneth Paltrow , Mickey R...  $200,000,000
# 3   Chris Hemsworth , Anthony Hopkins , Natalie Po...  $150,000,000
# 4     Chris Evans ,  Hugo Weaving , Samuel L. Jackson  $140,000,000
# 5   Robert Downey Jr. , Chris Evans , Scarlett Joh...  $220,000,000
# 6    Robert Downey Jr. , Gweneth Paltrow , Guy Pearce  $200,000,000
# 7   Chris Hemsworth ,  Natalie Portman , Tom Hiddl...  $170,000,000
# 8   Chris Evans , Scarlett Johansson , Samuel L. J...  $170,000,000
# 9            Chris Patt , Vin Diesel , Bradely Cooper  $170,000,000
# 10  Robert Downey Jr. , Chris Evans , Chris Hemswo...  $250,000,000
# 11          Paul Rudd , Michael Douglas , Corey Stall  $130,000,000
# 12  Robert Downey Jr. , Chris Evans , Scarlett Joh...  $250,000,000
# 13  Benedict Cumberbatch , Chiswetel Ejiofor , Rac...  $165,000,000
# 14  Chris Patt ,  Zoe Saldana , Dave Bautista , Vi...  $200,000,000
# 15   Tom Holland , Michael Keaton , Robert Downey Jr.  $175,000,000
# 16  Chris Hemsworth ,  Cate Blanchett , Tom Hiddle...  $180,000,000
# 17  Chadwick Boseman , Michael B. Jordan , Lupita ...  $200,000,000
# 18  Robert Downey Jr. , Chris Evans , Chris Hemswo...  $300,000,000
# 19        Paul Rudd , Evangeline Lilly , Micheal Pena  $130,000,000
# 20   Brie Larson , Samuel L. Jackson , Ben Mendelsohn  $160,000,000
# 21  Robert Downey Jr. , Chris Evans , Chris Hemswo...  $356,000,000
# 22  Tom Holland , Samuel L. Jackson , Jake Gyllenhaal  $160,000,000
#
#    Domestic Gross     Total Gross Opening Gross  Oscar Nomination  Oscar won  \
# 0    $318,604,126    $585,366,247   $98,618,668                 2          0
# 1    $134,806,913    $264,770,996   $55,414,050                 0          0
# 2    $312,433,331    $623,933,331  $128,122,480                 1          0
# 3    $181,030,624    $449,326,618   $65,723,338                 0          0
# 4    $176,654,505    $370,569,774   $65,058,524                 0          0
# 5    $623,357,910  $1,518,812,988  $207,438,708                 1          0
# 6    $408,992,272  $1,214,811,252  $174,144,585                 1          0
# 7    $206,362,140    $644,783,140   $85,737,841                 0          0
# 8    $259,746,958    $714,421,503   $95,023,721                 1          0
# 9    $333,714,112    $772,776,600   $94,320,883                 2          0
# 10   $459,005,868  $1,402,805,868  $191,271,109                 0          0
# 11   $180,202,163    $519,311,965   $57,225,526                 0          0
# 12   $408,084,349  $1,153,296,293  $179,139,142                 0          0
# 13   $232,641,920    $677,718,395   $85,058,311                 1          0
# 14   $389,813,101    $863,756,051  $146,510,104                 1          0
# 15   $334,201,140    $880,166,924  $117,027,503                 0          0
# 16    $315,058,28    $853,977,126  $122,744,989                 0          0
# 17    $700,059,56  $1,346,913,161  $202,003,951                 7          3
# 18   $678,815,482  $2,048,359,754  $257,698,183                 1          0
# 19   $216,648,740    $622,674,139   $75,812,205                 0          0
# 20   $426,829,839  $1,128,274,794  $153,433,423                 0          0
# 21   $858,373,000  $2,797,501,328  $357,115,007                 1          0
# 22   $390,532,085  $1,131,927,996   $92,579,212                 0          0
#
#     Phase  Budgetint  Total Gross Int  Total Profit  Review to Budget
# 0       1  140000000        585366247     445366247      5.642857e-07
# 1       1  150000000        264770996     114770996      4.066667e-07
# 2       1  200000000        623933331     423933331      2.850000e-07
# 3       1  150000000        449326618     299326618      3.800000e-07
# 4       1  140000000        370569774     230569774      4.714286e-07
# 5       1  220000000       1518812988    1298812988      3.136364e-07
# 6       2  200000000       1214811252    1014811252      3.100000e-07
# 7       2  170000000        644783140     474783140      3.176471e-07
# 8       2  170000000        714421503     544421503      4.117647e-07
# 9       2  170000000        772776600     602776600      4.470588e-07
# 10      2  250000000       1402805868    1152805868      2.640000e-07
# 11      2  130000000        519311965     389311965      4.923077e-07
# 12      3  250000000       1153296293     903296293      3.000000e-07
# 13      3  165000000        677718395     512718395      4.363636e-07
# 14      3  200000000        863756051     663756051      3.350000e-07
# 15      3  175000000        880166924     705166924      4.171429e-07
# 16      3  180000000        853977126     673977126      4.111111e-07
# 17      3  200000000       1346913161    1146913161      4.400000e-07
# 18      3  300000000       2048359754    1748359754      2.266667e-07
# 19      3  130000000        622674139     492674139      5.384615e-07
# 20      3  160000000       1128274794     968274794      4.000000e-07
# 21      3  356000000       2797501328    2441501328      2.191011e-07
# 22      3  160000000       1131927996     971927996      4.312500e-07

# %% [markdown]
# Showing the graph that budgets are not generally increasing over time.

# %%
plt.figure(figsize=(40, 6))
#making a bar chart to show the data in a presentation
plt.plot(mcu['US release Date'],mcu['Budgetint'], color='red')

plt.title("Line Plot of budget of movies over time")
plt.xlabel("Date")
plt.ylabel("Budget")

plt.show()

# %% [markdown]
# Now we have extablished the pattern no matter how we filter the data it  show academic preformance below 2 is consentrated
# around having 3 stress factors

# %%
mcu.corr()['metascore']
# Out:
# C:\Users\ryan\AppData\Local\Temp\ipykernel_15212\1284292374.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mcu.corr()['metascore']
# IMDB rating         0.595956
# metascore           1.000000
# Oscar Nomination    0.632156
# Oscar won           0.533457
# Phase               0.444387
# Budgetint           0.242615
# Total Gross Int     0.373324
# Total Profit        0.383131
# Review to Budget    0.260104
# Name: metascore, dtype: float64

# %% [markdown]
# There are appears to be little reationship between budget and metascore, so spending more money on movies doesn't improve the score. What is the average metascore of the MCU universe

# %%
print("The Metascore avereage rating is ",mcu["metascore"].mean())
print("IMDB Rating has an average score of ",mcu["IMDB rating"].mean())
# Out:
# The Metascore avereage rating is  68.65217391304348
# IMDB Rating has an average score of  7.4434782608695675

# %% [markdown]
# What cast member is in the most number of movies.

# %%
casts = [
    "Robert Downey Jr.",
    'Gweneth Paltrow ',
    'Terrence Howard',
    'Edward Norton',
    'Liv Tyler',
    'Tim Roth',
    'Mickey Rourke',
    'Chris Hemsworth',
    'Anthony Hopkins',
    'Natalie Portman',
    'Chris Evans',
    'Hugo Weaving',
    'Samuel L. Jackson',
    'Scarlett Johansson',
    'Jeremy Renner',
    'Guy Pearce',
    'Tom Hiddleston',
    'Chris Patt', 
    'Vin Diesel',
    'Bradely Cooper',
    'Mark Ruffalo',
    'Paul Rudd',
    'Michael Douglas',
    'Corey Stall',
    'Sebastian Stan',
    'Benedict Cumberbatch',
    'Chiswetel Ejiofor',
    'Racheal McAdams',
    'Zoe Saldana',
    'Dave Bautista',
    'Michael Keaton',
    'Cate Blanchett',
    'Chadwick Boseman',
    'Michael B. Jordan',
    "Josh Brolin",
    "Jake Gyllenhaal",
    "Lupita Nyong'o"
]
max = 0
for cast in casts:
    cast_count = mcu[mcu["Cast"].str.contains(cast)]
    print(cast, " has the count", cast_count.shape[0])

#The MCU charater with the most movie entries is robert Downey Jr.
# Out:
# Robert Downey Jr.  has the count 9
# Gweneth Paltrow   has the count 3
# Terrence Howard  has the count 1
# Edward Norton  has the count 1
# Liv Tyler  has the count 1
# Tim Roth  has the count 1
# Mickey Rourke  has the count 1
# Chris Hemsworth  has the count 6
# Anthony Hopkins  has the count 1
# Natalie Portman  has the count 2
# Chris Evans  has the count 7
# Hugo Weaving  has the count 1
# Samuel L. Jackson  has the count 4
# Scarlett Johansson  has the count 3
# Jeremy Renner  has the count 1
# Guy Pearce  has the count 1
# Tom Hiddleston  has the count 2
# Chris Patt  has the count 2
# Vin Diesel  has the count 2
# Bradely Cooper  has the count 1
# Mark Ruffalo  has the count 3
# Paul Rudd  has the count 2
# Michael Douglas  has the count 1
# Corey Stall  has the count 1
# Sebastian Stan  has the count 1
# Benedict Cumberbatch  has the count 1
# Chiswetel Ejiofor  has the count 1
# Racheal McAdams  has the count 1
# Zoe Saldana  has the count 1
# Dave Bautista  has the count 1
# Michael Keaton  has the count 1
# Cate Blanchett  has the count 1
# Chadwick Boseman  has the count 1
# Michael B. Jordan  has the count 1
# Josh Brolin  has the count 2
# Jake Gyllenhaal  has the count 1
# Lupita Nyong'o  has the count 1

# %% [markdown]
# The MCU charater with the most movie entries is robert Downey Jr.

# %%
casts = [
   "Robert Downey Jr.",
    'Gweneth Paltrow ',
    'Terrence Howard',
    'Edward Norton',
    'Liv Tyler',
    'Tim Roth',
    'Mickey Rourke',
    'Chris Hemsworth',
    'Anthony Hopkins',
    'Natalie Portman',
    'Chris Evans',
    'Hugo Weaving',
    'Samuel L. Jackson',
    'Scarlett Johansson',
    'Jeremy Renner',
    'Guy Pearce',
    'Tom Hiddleston',
    'Chris Patt', 
    'Vin Diesel',
    'Bradely Cooper',
    'Mark Ruffalo',
    'Paul Rudd',
    'Michael Douglas',
    'Corey Stall',
    'Sebastian Stan',
    'Benedict Cumberbatch',
    'Chiswetel Ejiofor',
    'Racheal McAdams',
    'Zoe Saldana',
    'Dave Bautista',
    'Michael Keaton',
    'Cate Blanchett',
    'Chadwick Boseman',
    'Michael B. Jordan',
    "Josh Brolin",
    "Jake Gyllenhaal",
    "Lupita Nyong'o"
]
char = ''
max = 0
for cast in casts:
    cast_count = mcu[mcu["Cast"].str.contains(cast)]
    print(cast, " has the average metascore",cast_count["metascore"].mean())
    if cast_count["metascore"].mean() > max:
        max = cast_count["metascore"].mean()
        char = cast
print("The charater with the highest metascore",char,"of",max)
# Out:
# Robert Downey Jr.  has the average metascore 69.66666666666667
# Gweneth Paltrow   has the average metascore 66.0
# Terrence Howard  has the average metascore 79.0
# Edward Norton  has the average metascore 61.0
# Liv Tyler  has the average metascore 61.0
# Tim Roth  has the average metascore 61.0
# Mickey Rourke  has the average metascore 57.0
# Chris Hemsworth  has the average metascore 66.16666666666667
# Anthony Hopkins  has the average metascore 57.0
# Natalie Portman  has the average metascore 55.5
# Chris Evans  has the average metascore 70.28571428571429
# Hugo Weaving  has the average metascore 66.0
# Samuel L. Jackson  has the average metascore 67.25
# Scarlett Johansson  has the average metascore 71.33333333333333
# Jeremy Renner  has the average metascore 69.0
# Guy Pearce  has the average metascore 62.0
# Tom Hiddleston  has the average metascore 64.0
# Chris Patt  has the average metascore 71.5
# Vin Diesel  has the average metascore 71.5
# Bradely Cooper  has the average metascore 76.0
# Mark Ruffalo  has the average metascore 70.66666666666667
# Paul Rudd  has the average metascore 67.0
# Michael Douglas  has the average metascore 64.0
# Corey Stall  has the average metascore 64.0
# Sebastian Stan  has the average metascore 75.0
# Benedict Cumberbatch  has the average metascore 72.0
# Chiswetel Ejiofor  has the average metascore 72.0
# Racheal McAdams  has the average metascore 72.0
# Zoe Saldana  has the average metascore 67.0
# Dave Bautista  has the average metascore 67.0
# Michael Keaton  has the average metascore 73.0
# Cate Blanchett  has the average metascore 74.0
# Chadwick Boseman  has the average metascore 88.0
# Michael B. Jordan  has the average metascore 88.0
# Josh Brolin  has the average metascore 73.0
# Jake Gyllenhaal  has the average metascore 69.0
# Lupita Nyong'o  has the average metascore 88.0
# The charater with the highest metascore Chadwick Boseman of 88.0

# %% [markdown]
# ###### - Multiplication

# %%
casts = [
    "Robert Downey Jr.",
    'Gweneth Paltrow ',
    'Terrence Howard',
    'Edward Norton',
    'Liv Tyler',
    'Tim Roth',
    'Mickey Rourke',
    'Chris Hemsworth',
    'Anthony Hopkins',
    'Natalie Portman',
    'Chris Evans',
    'Hugo Weaving',
    'Samuel L. Jackson',
    'Scarlett Johansson',
    'Jeremy Renner',
    'Guy Pearce',
    'Tom Hiddleston',
    'Chris Patt', 
    'Vin Diesel',
    'Bradely Cooper',
    'Mark Ruffalo',
    'Paul Rudd',
    'Michael Douglas',
    'Corey Stall',
    'Sebastian Stan',
    'Benedict Cumberbatch',
    'Chiswetel Ejiofor',
    'Racheal McAdams',
    'Zoe Saldana',
    'Dave Bautista',
    'Michael Keaton',
    'Cate Blanchett',
    'Chadwick Boseman',
    'Michael B. Jordan',
    "Josh Brolin",
    "Jake Gyllenhaal",
    "Lupita Nyong'o"
]
char = ''
max = 0
for cast in casts:
    cast_count = mcu[mcu["Cast"].str.contains(cast)]
    print(cast, " has the Total Gross",cast_count["Total Gross Int"].sum())
    if cast_count["Total Gross Int"].sum() > max:
        max = cast_count["Total Gross Int"].sum()
        char = cast
print("The charater with the Total Gross int",char,"of",max)
# Out:
# Robert Downey Jr.  has the Total Gross 12225053985
# Gweneth Paltrow  has the Total Gross 2424110830
# Terrence Howard  has the Total Gross 585366247
# Edward Norton  has the Total Gross 264770996
# Liv Tyler  has the Total Gross 264770996
# Tim Roth  has the Total Gross 264770996
# Mickey Rourke  has the Total Gross 623933331
# Chris Hemsworth  has the Total Gross 8196753834
# Anthony Hopkins  has the Total Gross 449326618
# Natalie Portman  has the Total Gross 1094109758
# Chris Evans  has the Total Gross 10005767508
# Hugo Weaving  has the Total Gross 370569774
# Samuel L. Jackson  has the Total Gross 3345194067
# Scarlett Johansson  has the Total Gross 3386530784
# Jeremy Renner  has the Total Gross 1518812988
# Guy Pearce  has the Total Gross 1214811252
# Tom Hiddleston  has the Total Gross 1498760266
# Chris Patt  has the Total Gross 1636532651
# Vin Diesel  has the Total Gross 1636532651
# Bradely Cooper  has the Total Gross 772776600
# Mark Ruffalo  has the Total Gross 6248666950
# The charater with the Total Gross int Robert Downey Jr. of 12225053985

# %% [markdown]
# The actor wih the msot total gross is Rober Downey Jr.

# %%
casts = [
    "Robert Downey Jr.",
    'Gweneth Paltrow ',
    'Terrence Howard',
    'Edward Norton',
    'Liv Tyler',
    'Tim Roth',
    'Mickey Rourke',
    'Chris Hemsworth',
    'Anthony Hopkins',
    'Natalie Portman',
    'Chris Evans',
    'Hugo Weaving',
    'Samuel L. Jackson',
    'Scarlett Johansson',
    'Jeremy Renner',
    'Guy Pearce',
    'Tom Hiddleston',
    'Chris Patt', 
    'Vin Diesel',
    'Bradely Cooper',
    'Mark Ruffalo',
    'Paul Rudd',
    'Michael Douglas',
    'Corey Stall',
    'Sebastian Stan',
    'Benedict Cumberbatch',
    'Chiswetel Ejiofor',
    'Racheal McAdams',
    'Zoe Saldana',
    'Dave Bautista',
    'Michael Keaton',
    'Cate Blanchett',
    'Chadwick Boseman',
    'Michael B. Jordan',
    "Josh Brolin",
    "Jake Gyllenhaal",
    "Lupita Nyong'o"
]
char = ''
max = 0
for cast in casts:
    cast_count = mcu[mcu["Cast"].str.contains(cast)]
    print(cast, " has the highest average IMDB rating",cast_count["IMDB rating"].mean())
    if cast_count["IMDB rating"].mean() > max:
        max = cast_count["IMDB rating"].mean()
        char = cast
print("The charater with the highest IMDB rating",char,"of",max)
# Out:
# Robert Downey Jr.  has the highest average IMDB rating 7.699999999999999
# Gweneth Paltrow   has the highest average IMDB rating 7.333333333333333
# Terrence Howard  has the highest average IMDB rating 7.9
# Edward Norton  has the highest average IMDB rating 6.6
# Liv Tyler  has the highest average IMDB rating 6.6
# Tim Roth  has the highest average IMDB rating 6.6
# Mickey Rourke  has the highest average IMDB rating 7.0
# Chris Hemsworth  has the highest average IMDB rating 7.633333333333333
# Anthony Hopkins  has the highest average IMDB rating 7.0
# Natalie Portman  has the highest average IMDB rating 6.9
# Chris Evans  has the highest average IMDB rating 7.785714285714286
# Hugo Weaving  has the highest average IMDB rating 6.9
# Samuel L. Jackson  has the highest average IMDB rating 7.2250000000000005
# Scarlett Johansson  has the highest average IMDB rating 7.833333333333333
# Jeremy Renner  has the highest average IMDB rating 8.0
# Guy Pearce  has the highest average IMDB rating 7.1
# Tom Hiddleston  has the highest average IMDB rating 7.35
# Chris Patt  has the highest average IMDB rating 7.8
# Vin Diesel  has the highest average IMDB rating 7.8
# Bradely Cooper  has the highest average IMDB rating 8.0
# Mark Ruffalo  has the highest average IMDB rating 8.033333333333333
# Paul Rudd  has the highest average IMDB rating 7.15
# Michael Douglas  has the highest average IMDB rating 7.3
# Corey Stall  has the highest average IMDB rating 7.3
# Sebastian Stan  has the highest average IMDB rating 7.8
# Benedict Cumberbatch  has the highest average IMDB rating 7.5
# Chiswetel Ejiofor  has the highest average IMDB rating 7.5
# Racheal McAdams  has the highest average IMDB rating 7.5
# Zoe Saldana  has the highest average IMDB rating 7.6
# Dave Bautista  has the highest average IMDB rating 7.6
# Michael Keaton  has the highest average IMDB rating 7.4
# Cate Blanchett  has the highest average IMDB rating 7.9
# Chadwick Boseman  has the highest average IMDB rating 7.3
# Michael B. Jordan  has the highest average IMDB rating 7.3
# Josh Brolin  has the highest average IMDB rating 8.4
# Jake Gyllenhaal  has the highest average IMDB rating 7.5
# Lupita Nyong'o  has the highest average IMDB rating 7.3
# The charater with the highest IMDB rating Josh Brolin of 8.4

# %% [markdown]
# Showing that profits are upward trending on the mcu

# %%
plt.figure(figsize=(40, 6))
#making a bar chart to show the data in a presentation
plt.plot(mcu['US release Date'],mcu['Total Gross Int'], color='red')

plt.title("Line Plot of Total Gross of movies over time")
plt.xlabel("Date")
plt.ylabel("Total Gross")

plt.show()

# %% [markdown]
# Showing the metascore is generally increasign overtime

# %%
plt.figure(figsize=(40, 6))
#making a bar chart to show the data in a presentation
plt.plot(mcu['US release Date'],mcu['metascore'], color='red')

plt.title("Line Plot of metascore of movies over time")
plt.xlabel("Date")
plt.ylabel("metascore")

plt.show()

# %% [markdown]
# Showing IMDB Rating is generally flat ling over time.

# %%
plt.figure(figsize=(40, 6))
#making a bar chart to show the data in a presentation
plt.plot(mcu['US release Date'],mcu['IMDB rating'], color='red')

plt.title("Line Plot of IMDB rating of movies over time")
plt.xlabel("Date")
plt.ylabel("IMDB Rating")

plt.show()
